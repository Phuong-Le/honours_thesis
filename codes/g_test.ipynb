# %%
from cogent3.util.deserialise import deserialise_object
from cogent3.maths.stats.contingency import CategoryCounts

# %%
diseases = deserialise_object('/Users/phuongle/Documents/repos/PhuongData/loop2_processed/loop2.json')['diseases']

# %%
for disease in diseases:
    path = f'/Users/phuongle/Documents/repos/PhuongAnalysis/results/loop2/gle/homogeneity_test_1_cancer/homogeneity_test_1_cancer_unique_mutpos_{disease}_wholegenome.json'
    out = deserialise_object(path)
    out=out.to_latex(label=f'tab:g-test_{disease}')
    print(out)
    print('blah blah')
    print('blah blah')
    print('blah blah')
    print('done')
# Out:
# \begin{table}[htp!]
# \centering
# \begin{tabular}{ r r r }
# \hline
# \bf{} & \bf{mutated} & \bf{non_mutated} \\
# \hline
# \hline
# closed &  152518 &  2807114120 \\
#   open &    3231 &    73763417 \\
# \hline
# \end{tabular}
# \label{tab:g-test_Bone-Osteosarc}
# \end{table}
# blah blah
# blah blah
# blah blah
# done
# \begin{table}[htp!]
# \centering
# \begin{tabular}{ r r r }
# \hline
# \bf{} & \bf{mutated} & \bf{non_mutated} \\
# \hline
# \hline
# closed &  650480 &  2808984887 \\
#   open &   17425 &    71380494 \\
# \hline
# \end{tabular}
# \label{tab:g-test_Breast-AdenoCa}
# \end{table}
# blah blah
# blah blah
# blah blah
# done
# \begin{table}[htp!]
# \centering
# \begin{tabular}{ r r r }
# \hline
# \bf{} & \bf{mutated} & \bf{non_mutated} \\
# \hline
# \hline
# closed &  189553 &  2813626572 \\
#   open &    3709 &    67213452 \\
# \hline
# \end{tabular}
# \label{tab:g-test_CNS-Medullo}
# \end{table}
# blah blah
# blah blah
# blah blah
# done
# \begin{table}[htp!]
# ...

# %%
help(out.to_latex)
# Out:
# Help on method to_latex in module cogent3.util.table:
#
# to_latex(concat_title_legend=True, justify=None, label=None, position=None) method of cogent3.util.table.Table instance
#     Returns the text a LaTeX table.
#
#     Parameters
#     ----------
#     concat_title_legend : bool
#         the table caption is formed by concatenating the table title and legend
#     rows
#         table data in row orientation
#     header
#         table header
#     justify
#         column justification, default is right aligned.
#     label
#         for cross referencing
#     position
#         table page position, default is here, top separate page
#
#     Notes
#     -----
#     The \caption*{} command is provided with the caption package. See
#     https://ctan.org/pkg/caption for more details.

# %%
from cogent3 import load_table

# %%
load_table('/Users/phuongle/Documents/repos/PhuongAnalysis/results/loop2/gle/homogeneity_post_analysis/homogeneity_post_analysis_1_cancer.tsv.gz')
# Out:
# ...
# disease                 phi    relative entropy    odds ratio    G-pval    number of donors    average number of mutations    total number of mutations
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Bone-Osteosarc       0.0002              0.0000        1.2404    0.0000                  44                      3791.9318                       166845
# Breast-AdenoCa      -0.0001              0.0000        0.9486    0.0000                 113                      6317.3009                       713855
# Breast-DCIS         -0.0000              0.0000        0.8725    0.1016                   3                      2005.0000                         6015
# Breast-LobularCa    -0.0000              0.0000        0.9640    0.4024                   7                      3252.5714                        22768
# ...
